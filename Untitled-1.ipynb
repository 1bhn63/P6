# %% [markdown]
# Практическая работа №5

# %% [markdown]
# Цель:реализовать базовый анализ датасета

# %%
import pandas as pd 
import numpy as np

titanic = pd.read_csv('titanic.csv')
titanic.head()
# Out:
# C:\Users\insai\AppData\Local\Temp\ipykernel_24944\3127194115.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
# ...

# %% [markdown]
# 1. Я Зенченко Богдан Алексеевич вывел начальные данные из своего датасета с этими стобцами Name	Sex	Age	Siblings/Spouses Aboard	Parents/Children Aboard	Fare

# %%
titanic.shape
# Out:
# (887, 8)

# %% [markdown]
# 2. Я Зенченко Богдан Алексееыич вывел размерность массива через метод Shape

# %%
titanic.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Siblings/Spouses Aboard',
#        'Parents/Children Aboard', 'Fare'],
#       dtype='object')

# %% [markdown]
# Я Зенченко Богдан Алексеевич вывел все названия колонок из своего датасета
# 'Name'
# 'Sex'
# 'Age'
# 'Siblings/Spouses Aboard'
# 'Parents/Children Aboard'
# 'Fare'

# %%
titanic ['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# 4. Я Зенченко Богдан Алексеевич вывел все уникальные данные а именно 'male', 'female' в стобце 'Sex' c помощью метода Unique

# %%
titanic.sort_values(by = 'Name')
# Out:
#      Survived  Pclass                                               Name  \
# 741         0       1                        Capt. Edward Gifford Crosby
# 691         0       1                                     Col. John Weir
# 644         1       1                 Col. Oberst Alfons Simonius-Blumer
# 30          0       1                            Don. Manuel E Uruchurtu
# 396         0       2                                    Dr. Alfred Pain
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 149         0       2                          Rev. Robert James Bateman
# 148         0       2                   Rev. Thomas Roussel Davids Byles
# 596         1       1                      Sir. Cosmo Edmund Duff Gordon
# 755         1       1  the Countess. of (Lucy Noel Martha Dyer-Edward...
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %% [markdown]
# 5. Я Зенченко Богдан Алексеевич отсортировал все данные по именам в алфовитном порядке с помощью метода sort_values

# %%
titanic.drop(columns=['Age'], inplace=True)

# %% [markdown]
# 6. Я Зенченко Богдан Алексеевич удалил колонку "Age" с помощью метода drop

# %%
titanic = titanic.replace({'Siblings/Spouses Aboard': np.nan}, 'Unknown')
titanic
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %% [markdown]
# 7. Я Зенченко Богдан Алексеевич заменил конкретные данные в колонке 'Siblings/Spouses Aboard' на Unknown с помощью метода replace

# %%
titanic =titanic.drop_duplicates()
titanic
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %% [markdown]
# 8. Я Зенченко Богдан Алексеевич удалил дубликаты в датасете с помощью метода drop_duplicates()

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Survived                 887 non-null    int64
#  1   Pclass                   887 non-null    int64
#  2   Name                     887 non-null    object
#  3   Sex                      887 non-null    object
#  4   Siblings/Spouses Aboard  887 non-null    int64
#  5   Parents/Children Aboard  887 non-null    int64
#  6   Fare                     887 non-null    float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 48.6+ KB

# %% [markdown]
# 9. Я Зенченко Богдан Алексеевич проанализировал свой датасет с помощью метода info

# %%
titanic.describe()
# Out:
#          Survived      Pclass  Siblings/Spouses Aboard  \
# count  887.000000  887.000000               887.000000
# mean     0.385569    2.305524                 0.525366
# std      0.487004    0.836662                 1.104669
# min      0.000000    1.000000                 0.000000
# 25%      0.000000    2.000000                 0.000000
# 50%      0.000000    3.000000                 0.000000
# 75%      1.000000    3.000000                 1.000000
# max      1.000000    3.000000                 8.000000
#
#        Parents/Children Aboard       Fare
# count               887.000000  887.00000
# mean                  0.383315   32.30542
# std                   0.807466   49.78204
# min                   0.000000    0.00000
# 25%                   0.000000    7.92500
# 50%                   0.000000   14.45420
# 75%                   0.000000   31.13750
# max                   6.000000  512.32920

# %% [markdown]
# 10.Я Зенченко Богдан Алексеевич c помощью метода describe провел статистический числвой анализ

# %%
titanic1 = titanic.loc[[0, 1, 2 ,3, 4, 5 ],['Survived',	'Pclass', 'Siblings/Spouses Aboard', 'Parents/Children Aboard',	'Fare']]
titanic1
# Out:
#    Survived  Pclass  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0         0       3                        1                        0   7.2500
# 1         1       1                        1                        0  71.2833
# 2         1       3                        0                        0   7.9250
# 3         1       1                        1                        0  53.1000
# 4         0       3                        0                        0   8.0500
# 5         0       3                        0                        0   8.4583

# %% [markdown]
# 11. Я Зенченко Богдан Алексеевич провел выборку данных по строкам и столбцам с помощью метода loc а именно вывел первые шесть ячейки с данными в таких колонках как: 'Survived',	'Pclass', 'Siblings/Spouses Aboard', 'Parents/Children Aboard',	'Fare'

# %%
titanic.to_csv("New_starWars.csv", index=True)
titanic
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %% [markdown]
#  12. Я Зенченко Богдан Алексеевич сохранил новый датасет при помощи метода to_csv

# %% [markdown]
# Вывод: в ходе практичсекой работы был произведен базовый анализ датасета при помощи таких методов как:  "head", "shape", "columns", "unique", "sort_values", "drop", "replace", "drop_duplicates", "info", "describe", "loc", "to_csv"
